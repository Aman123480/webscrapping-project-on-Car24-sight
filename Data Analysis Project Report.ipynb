# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import re

# %%
URL = 'https://www.cars24.com/buy-used-car?sort=P&search=HONDA&storeCityId=2&pinId=110001'

# %%
page = requests.get(URL)

# %%
print(page.status_code)
# Out:
# 200

# %%
htmlcode = page.text

# %%
htmlcode
# Out:
# '<!DOCTYPE html>\n\n<html lang="en">\n\n<head>\n    <link rel="preconnect" href="//www.googleoptimize.com" />\n    <link rel="preconnect" href="//www.googletagmanager.com" />\n    <link rel="preconnect" href="//www.google-analytics.com" />\n    <link rel="preconnect" href="//connect.facebook.net" />\n    <link rel="preconnect" href="//cdn.jsdelivr.net" />\n    <link rel="preconnect" href="//widgets.getsitecontrol.com" />\n    <link rel="preconnect" href="//s.yimg.com" />\n    <link rel="preconnect" href="//www.googleadservices.com" />\n    <link rel="preconnect" href="//d2r1yp2w7bby2u.cloudfront.net" /><meta charset="UTF-8">\n  <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" />\n  <meta property="fb:app_id" content="697234207046254" /><!--scripts from helmet--><link data-react-helmet="true" href="https://www.cars24.com/buy-used-car/" rel="canonical"/><link data-react-helmet="true" rel="preload" href="https://fastly-production.
# ...

# %%
soup = BeautifulSoup(htmlcode)

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <link href="//www.googleoptimize.com" rel="preconnect"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <link href="//www.google-analytics.com" rel="preconnect"/>
#   <link href="//connect.facebook.net" rel="preconnect"/>
#   <link href="//cdn.jsdelivr.net" rel="preconnect"/>
#   <link href="//widgets.getsitecontrol.com" rel="preconnect"/>
#   <link href="//s.yimg.com" rel="preconnect"/>
#   <link href="//www.googleadservices.com" rel="preconnect"/>
#   <link href="//d2r1yp2w7bby2u.cloudfront.net" rel="preconnect"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
#   <meta content="697234207046254" property="fb:app_id"/>
#   <!--scripts from helmet-->
#   <link data-react-helmet="true" href="https://www.cars24.com/buy-used-car/" rel="canonical"/>
# ...

# %%
Model = soup.find('h2',attrs={'class':'_3FpCg'})

# %%
Model.text
# Out:
# '2017 Honda City'

# %%
Emi_month = soup.find('div',attrs={'class':'_2HFRN'})

# %%
Emi_month.text
# Out:
# '₹17,328/month'

# %%
Feature = soup.find('ul',attrs={'class':'bVR0c'})

# %%
Feature.text
# Out:
# '26,236 km1st OwnerPetrol'

# %%
brand = soup.find('div',attrs={'class':'_1J_9o _3UMoO'})

# %%
brand.text
# Out:
# 'MarutiHyundaiHondaTataToyota'

# %%
Overall_Amt = soup.find('div',attrs={'class':'_7udZZ'})

# %%
Overall_Amt.text
# Out:
# '₹7,78,999'

# %%
Models = soup.find_all('h2',attrs={'class':'_3FpCg'})

# %%
for tag in Models:
    print(tag.text)
# Out:
# 2017 Honda City
# 2019 Honda City
# 2016 Honda Brio
# 2020 Honda City
# 2016 Honda CRV
# 2013 Honda Amaze
# 2018 Honda Jazz
# 2020 Honda City
# 2018 Honda Amaze
# 2014 Honda Amaze
# 2021 Honda Jazz
# 2017 Honda Amaze
# 2018 Honda Amaze
# 2013 Honda Amaze
# 2018 Honda City
# 2012 Honda Brio
# 2015 Honda City
# 2014 Honda City
# 2011 Honda City
# 2010 Honda City

# %%
Features = soup.find_all('ul',attrs={'class':'bVR0c'})

# %%
for tag in Features:
    print(tag.text)
# Out:
# 26,236 km1st OwnerPetrol
# 41,091 km1st OwnerPetrol
# 23,791 km1st OwnerPetrol
# 12,934 km1st OwnerPetrol
# 1,03,602 km2nd OwnerPetrol
# 48,118 km1st OwnerDiesel
# 23,733 km2nd OwnerPetrol
# 29,009 km1st OwnerPetrol
# 17,205 km1st OwnerPetrol
# 85,083 km1st OwnerPetrol
# 6,910 km1st OwnerPetrol
# 11,067 km1st OwnerPetrol
# 29,226 km1st OwnerPetrol
# 31,102 km1st OwnerPetrol
# 32,309 km1st OwnerPetrol
# 57,694 km1st OwnerPetrol
# 48,989 km1st OwnerPetrol
# 79,898 km1st OwnerDiesel
# 67,428 km1st OwnerPetrol
# 36,895 km2nd OwnerPetrol

# %%
brands = soup.find_all('div',attrs={'class':'_1J_9o _3UMoO'})

# %%
for tag in brands:
    print(tag.text)
# Out:
# MarutiHyundaiHondaTataToyota
# Cars under 2 lakhCars between 2 lakh - 5 lakhCars between 5 lakh - 10 lakhCars above 10 lakh
# PetrolDieselCNGLPGElectricHybrid

# %%
Emi_months = soup.find_all('div',attrs={'class':'_2HFRN'})

# %%
for tag in Emi_months:
    print(tag.text)
# Out:
# ₹17,328/month
# ₹20,182/month
# ₹9,625/month
# ₹28,480/month
# ₹24,716/month
# ₹6,840/month
# ₹13,376/month
# ₹28,068/month
# ₹16,025/month
# ₹9,036/month
# ₹23,099/month
# ₹12,366/month
# ₹15,709/month
# ₹9,369/month
# ₹20,612/month
# ₹6,689/month
# ₹12,528/month
# ₹10,602/month
# ₹8,858/month
# ₹7,650/month

# %%
Overall_Amts = soup.find_all('div',attrs={'class':'_7udZZ'})

# %%
for tag in Overall_Amts:
    print(tag.text)
# Out:
# ₹7,78,999
# ₹9,07,299
# ₹4,32,699
# ₹12,80,299
# ₹11,11,099
# ₹3,07,499
# ₹6,01,299
# ₹12,61,799
# ₹7,20,399
# ₹4,06,199
# ₹10,38,399
# ₹5,55,899
# ₹7,06,199
# ₹4,21,199
# ₹9,26,599
# ₹3,00,699
# ₹5,63,199
# ₹4,76,599
# ₹3,98,199
# ₹3,43,899

# %%
#pages of url in car24

for i in range(1,31):
    URL='https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page={}'.format(i)
    print(URL)
# Out:
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=1
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=2
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=3
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=4
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=5
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=6
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=7
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=8
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=9
# https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page=10
# ...

# %%
Title = []
Emi_month=[]
Feature=[]
brand=[]
Overall_Amt=[]

for i in range (1,31):
    url='https://www.cars24.com/buy-used-car/?sort=P&search=HONDA&storeCityId=2&pinId=110001&page={}'.format(i)
    pages = requests.get(url)
    soup = BeautifulSoup(pages.text)

    for x in soup.find_all('div',class_="_1l4fi"):

        Titles=x.find("h2",class_="_3FpCg")
        if Titles is None:
            Title.append(np.NaN)
        else:
            Title.append(Titles.text)
            
        Emi_months=x.find("div",class_="_2HFRN")
        if Emi_months is None:
            Emi_month.append(np.NaN)
        else:
            Emi_month.append(Emi_months.text)
                
            
        Features=x.find("ul",class_="bVR0c")
        if Features is None:
            Feature.append(np.NaN)
        else:
            Feature.append(Features.text)
                
                
        Overall_Amts=x.find("div",class_="_7udZZ")
        if Overall_Amts is None:
            Overall_Amt.append(np.NaN)
        else:
            Overall_Amt.append(Overall_Amts.text)

# %%
df = pd.DataFrame({'Title':Title,'Emi_month':Emi_month,'Feature':Feature,'Overall_Amt':Overall_Amt})

# %%
Overall_Amts.text
# Out:
# '₹3,43,899'

# %%
df['Year of Manufacture'] = df['Title'].apply(lambda x: x.split(' ')[0])
df['Brand'] = df['Title'].apply(lambda x: x.split(' ')[1])
df['Model'] = df['Title'].apply(lambda x: x.split(' ')[2])
df['Number of Km'] = df['Feature'].apply(lambda x: x.split(' ')[0])
df['owner'] = df['Feature'].apply(lambda x: x.split(' ')[1])

# %%
for i in df['Emi_month']:
    print(i)
# Out:
# ₹17,328/month
# ₹20,182/month
# ₹9,625/month
# ₹28,480/month
# ₹24,716/month
# ₹6,840/month
# ₹13,376/month
# ₹28,068/month
# ₹16,025/month
# ₹9,036/month
# ₹23,099/month
# ₹12,366/month
# ₹15,709/month
# ₹9,369/month
# ₹20,612/month
# ₹6,689/month
# ₹12,528/month
# ₹10,602/month
# ₹8,858/month
# ₹7,650/month
# ₹17,328/month
# ₹20,182/month
# ₹9,625/month
# ₹28,480/month
# ₹24,716/month
# ₹6,840/month
# ₹13,376/month
# ₹28,068/month
# ₹16,025/month
# ₹9,036/month
# ₹23,099/month
# ₹12,366/month
# ₹15,709/month
# ₹9,369/month
# ₹20,612/month
# ₹6,689/month
# ₹12,528/month
# ₹10,602/month
# ₹8,858/month
# ₹7,650/month
# ₹24,716/month
# ₹13,376/month
# ₹17,328/month
# ₹6,840/month
# ₹20,182/month
# ₹28,480/month
# ₹9,625/month
# ₹28,068/month
# ₹16,025/month
# ₹9,036/month
# ₹23,099/month
# ₹12,366/month
# ₹9,369/month
# ₹15,709/month
# ₹20,612/month
# ₹6,689/month
# ₹12,528/month
# ₹10,602/month
# ₹8,858/month
# ₹7,650/month
# ₹24,716/month
# ₹13,376/month
# ₹17,328/month
# ...

# %%
df.shape
# Out:
# (600, 9)

# %%
df.tail()
# Out:
#                Title      Emi_month                   Feature Overall_Amt  \
# 595  2012 Honda Brio   ₹6,689/month  57,694 km1st OwnerPetrol   ₹3,00,699
# 596  2015 Honda City  ₹12,528/month  48,989 km1st OwnerPetrol   ₹5,63,199
# 597  2014 Honda City  ₹10,602/month  79,898 km1st OwnerDiesel   ₹4,76,599
# 598  2011 Honda City   ₹8,858/month  67,428 km1st OwnerPetrol   ₹3,98,199
# 599  2010 Honda City   ₹7,650/month  36,895 km2nd OwnerPetrol   ₹3,43,899
#
#     Year of Manufacture  Brand Model Number of Km  owner
# 595                2012  Honda  Brio       57,694  km1st
# 596                2015  Honda  City       48,989  km1st
# 597                2014  Honda  City       79,898  km1st
# 598                2011  Honda  City       67,428  km1st
# 599                2010  Honda  City       36,895  km2nd

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                600 non-null    object
#  1   Emi_month            600 non-null    object
#  2   Feature              600 non-null    object
#  3   Overall_Amt          600 non-null    object
#  4   Year of Manufacture  600 non-null    object
#  5   Brand                600 non-null    object
#  6   Model                600 non-null    object
#  7   Number of Km         600 non-null    object
#  8   owner                600 non-null    object
# dtypes: object(9)
# memory usage: 42.3+ KB

# %%
df.to_csv('car24.csv',index=False)

# %%
#load a dataframe from csv

df=pd.read_csv('car24.csv')

# %%
df.head()
# Out:
#              Title      Emi_month                     Feature Overall_Amt  \
# 0  2017 Honda City  ₹17,328/month    26,236 km1st OwnerPetrol   ₹7,78,999
# 1  2019 Honda City  ₹20,182/month    41,091 km1st OwnerPetrol   ₹9,07,299
# 2  2016 Honda Brio   ₹9,625/month    23,791 km1st OwnerPetrol   ₹4,32,699
# 3  2020 Honda City  ₹28,480/month    12,934 km1st OwnerPetrol  ₹12,80,299
# 4   2016 Honda CRV  ₹24,716/month  1,03,602 km2nd OwnerPetrol  ₹11,11,099
#
#    Year of Manufacture  Brand Model Number of Km  owner
# 0                 2017  Honda  City       26,236  km1st
# 1                 2019  Honda  City       41,091  km1st
# 2                 2016  Honda  Brio       23,791  km1st
# 3                 2020  Honda  City       12,934  km1st
# 4                 2016  Honda   CRV     1,03,602  km2nd

# %%
regex = 'Petrol|Diesel(?:)'
df['Fuel type'] = df['Feature'].apply(lambda x: re.findall(regex,x))
df['Fuel type'] = df['Fuel type'].apply(lambda x:''.join(x))

# %%
df['Fuel type']
# Out:
# 0      Petrol
# 1      Petrol
# 2      Petrol
# 3      Petrol
# 4      Petrol
#         ...
# 595    Petrol
# 596    Petrol
# 597    Diesel
# 598    Petrol
# 599    Petrol
# Name: Fuel type, Length: 600, dtype: object

# %%
df.head(9)
# Out:
#               Title  Emi_month                     Feature  Overall_Amt  \
# 0   2017 Honda City    17328.0    26,236 km1st OwnerPetrol     778999.0
# 1   2019 Honda City    20182.0    41,091 km1st OwnerPetrol     907299.0
# 2   2016 Honda Brio     9625.0    23,791 km1st OwnerPetrol     432699.0
# 3   2020 Honda City    28480.0    12,934 km1st OwnerPetrol    1280299.0
# 4    2016 Honda CRV    24716.0  1,03,602 km2nd OwnerPetrol    1111099.0
# 5  2013 Honda Amaze     6840.0    48,118 km1st OwnerDiesel     307499.0
# 6   2018 Honda Jazz    13376.0    23,733 km2nd OwnerPetrol     601299.0
# 7   2020 Honda City    28068.0    29,009 km1st OwnerPetrol    1261799.0
# 8  2018 Honda Amaze    16025.0    17,205 km1st OwnerPetrol     720399.0
#
#    Year of Manufacture  Brand  Model  Number of Km owner Fuel type
# 0                 2017  Honda   City       26236.0   1st    Petrol
# 1                 2019  Honda   City       41091.0   1st    Petrol
# ...

# %%
df['Emi_month'] = df['Emi_month'].apply(lambda x: x.replace(',',''))

# %%
df['Emi_month']
# Out:
# 0      ₹17328/month
# 1      ₹20182/month
# 2       ₹9625/month
# 3      ₹28480/month
# 4      ₹24716/month
#            ...
# 595     ₹6689/month
# 596    ₹12528/month
# 597    ₹10602/month
# 598     ₹8858/month
# 599     ₹7650/month
# Name: Emi_month, Length: 600, dtype: object

# %%
df.head()
# Out:
#              Title     Emi_month                     Feature Overall_Amt  \
# 0  2017 Honda City  ₹17328/month    26,236 km1st OwnerPetrol   ₹7,78,999
# 1  2019 Honda City  ₹20182/month    41,091 km1st OwnerPetrol   ₹9,07,299
# 2  2016 Honda Brio   ₹9625/month    23,791 km1st OwnerPetrol   ₹4,32,699
# 3  2020 Honda City  ₹28480/month    12,934 km1st OwnerPetrol  ₹12,80,299
# 4   2016 Honda CRV  ₹24716/month  1,03,602 km2nd OwnerPetrol  ₹11,11,099
#
#    Year of Manufacture  Brand Model Number of Km  owner Fuel type
# 0                 2017  Honda  City       26,236  km1st    Petrol
# 1                 2019  Honda  City       41,091  km1st    Petrol
# 2                 2016  Honda  Brio       23,791  km1st    Petrol
# 3                 2020  Honda  City       12,934  km1st    Petrol
# 4                 2016  Honda   CRV     1,03,602  km2nd    Petrol

# %%
df['Emi_month'] = df['Emi_month'].apply(lambda x: x.replace('₹',''))
df['Emi_month'] = df['Emi_month'].apply(lambda x: x.replace('month',''))
df['Emi_month'] = df['Emi_month'].apply(lambda x: x.replace('/',''))

# %%
df.head()
# Out:
#              Title Emi_month                     Feature Overall_Amt  \
# 0  2017 Honda City     17328    26,236 km1st OwnerPetrol   ₹7,78,999
# 1  2019 Honda City     20182    41,091 km1st OwnerPetrol   ₹9,07,299
# 2  2016 Honda Brio      9625    23,791 km1st OwnerPetrol   ₹4,32,699
# 3  2020 Honda City     28480    12,934 km1st OwnerPetrol  ₹12,80,299
# 4   2016 Honda CRV     24716  1,03,602 km2nd OwnerPetrol  ₹11,11,099
#
#    Year of Manufacture  Brand Model Number of Km  owner Fuel type
# 0                 2017  Honda  City       26,236  km1st    Petrol
# 1                 2019  Honda  City       41,091  km1st    Petrol
# 2                 2016  Honda  Brio       23,791  km1st    Petrol
# 3                 2020  Honda  City       12,934  km1st    Petrol
# 4                 2016  Honda   CRV     1,03,602  km2nd    Petrol

# %%
df['owner'] = df['owner'].apply(lambda x: x.replace('km',''))

# %%
df.head()
# Out:
#              Title Emi_month                     Feature Overall_Amt  \
# 0  2017 Honda City     17328    26,236 km1st OwnerPetrol   ₹7,78,999
# 1  2019 Honda City     20182    41,091 km1st OwnerPetrol   ₹9,07,299
# 2  2016 Honda Brio      9625    23,791 km1st OwnerPetrol   ₹4,32,699
# 3  2020 Honda City     28480    12,934 km1st OwnerPetrol  ₹12,80,299
# 4   2016 Honda CRV     24716  1,03,602 km2nd OwnerPetrol  ₹11,11,099
#
#    Year of Manufacture  Brand Model Number of Km owner Fuel type
# 0                 2017  Honda  City       26,236   1st    Petrol
# 1                 2019  Honda  City       41,091   1st    Petrol
# 2                 2016  Honda  Brio       23,791   1st    Petrol
# 3                 2020  Honda  City       12,934   1st    Petrol
# 4                 2016  Honda   CRV     1,03,602   2nd    Petrol

# %%
df['Overall_Amt'] = df['Overall_Amt'].apply(lambda x: x.replace('₹',''))
df['Overall_Amt'] = df['Overall_Amt'].apply(lambda x: x.replace(',',''))

# %%
df.drop(['Title','Feature'], axis = 1)
# Out:
#     Emi_month Overall_Amt  Year of Manufacture  Brand Model Number of Km  \
# 0       17328      778999                 2017  Honda  City       26,236
# 1       20182      907299                 2019  Honda  City       41,091
# 2        9625      432699                 2016  Honda  Brio       23,791
# 3       28480     1280299                 2020  Honda  City       12,934
# 4       24716     1111099                 2016  Honda   CRV     1,03,602
# ..        ...         ...                  ...    ...   ...          ...
# 595      6689      300699                 2012  Honda  Brio       57,694
# 596     12528      563199                 2015  Honda  City       48,989
# 597     10602      476599                 2014  Honda  City       79,898
# 598      8858      398199                 2011  Honda  City       67,428
# 599      7650      343899                 2010  Honda  City       36,895
#
#     owner Fuel type
# 0     1st    Petrol
# 1     1st    Petrol
# 2     1st    Petrol
# ...

# %%
df['Number of Km'] = df['Number of Km'].apply(lambda x: x.replace(',',''))

# %%
df['Number of Km'] = df['Number of Km'].astype(float)
df['Overall_Amt'] = df['Overall_Amt'].astype(float)
df['Emi_month'] = df['Emi_month'].astype(float)
df.head()
# Out:
#              Title  Emi_month                     Feature  Overall_Amt  \
# 0  2017 Honda City    17328.0    26,236 km1st OwnerPetrol     778999.0
# 1  2019 Honda City    20182.0    41,091 km1st OwnerPetrol     907299.0
# 2  2016 Honda Brio     9625.0    23,791 km1st OwnerPetrol     432699.0
# 3  2020 Honda City    28480.0    12,934 km1st OwnerPetrol    1280299.0
# 4   2016 Honda CRV    24716.0  1,03,602 km2nd OwnerPetrol    1111099.0
#
#    Year of Manufacture  Brand Model  Number of Km owner Fuel type
# 0                 2017  Honda  City       26236.0   1st    Petrol
# 1                 2019  Honda  City       41091.0   1st    Petrol
# 2                 2016  Honda  Brio       23791.0   1st    Petrol
# 3                 2020  Honda  City       12934.0   1st    Petrol
# 4                 2016  Honda   CRV      103602.0   2nd    Petrol

# %%
df.drop(['Title','Feature'], axis = 1)
# Out:
#      Emi_month  Overall_Amt  Year of Manufacture  Brand Model  Number of Km  \
# 0      17328.0     778999.0                 2017  Honda  City       26236.0
# 1      20182.0     907299.0                 2019  Honda  City       41091.0
# 2       9625.0     432699.0                 2016  Honda  Brio       23791.0
# 3      28480.0    1280299.0                 2020  Honda  City       12934.0
# 4      24716.0    1111099.0                 2016  Honda   CRV      103602.0
# ..         ...          ...                  ...    ...   ...           ...
# 595     6689.0     300699.0                 2012  Honda  Brio       57694.0
# 596    12528.0     563199.0                 2015  Honda  City       48989.0
# 597    10602.0     476599.0                 2014  Honda  City       79898.0
# 598     8858.0     398199.0                 2011  Honda  City       67428.0
# 599     7650.0     343899.0                 2010  Honda  City       36895.0
#
#     owner Fuel type
# 0     1st    Petrol
# ...

# %%
#data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(10,5))
sns.countplot(x=df['Year of Manufacture'])
# Out:
# <AxesSubplot:xlabel='Year of Manufacture', ylabel='count'>

# %%
plt.figure(figsize=(10,10))
sns.histplot(x=df['Year of Manufacture'])
# Out:
# <AxesSubplot:xlabel='Year of Manufacture', ylabel='Count'>

# %%
plt.figure(figsize=(10,5))
sns.boxplot(x =df['Model'], y =df['Year of Manufacture'])
# Out:
# <AxesSubplot:xlabel='Model', ylabel='Year of Manufacture'>

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x=df['Year of Manufacture'], y=df['Fuel type'])
plt.grid()

# %%
plt.figure(figsize=(20,7))
sns.barplot(x='Model', y='Number of Km', data=df)
plt.show()

# %%
Model=[4,32,64,128,256]
labels=['Model-4','Model-32','Model-64','Model-128','Model-256']
colors = sns.color_palette('bright')[0:5]
plt.pie(Model,labels=labels, colors = colors, autopct='%.0f%%')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.scatterplot(data=df, x='Model', y='Emi_month', hue='Number of Km',
    sizes=(50,50), legend="full")
plt.grid()

# %%
plt.figure(figsize=(10,10))
sns.jointplot(x='Model', y='Emi_month',data=df,kind='scatter')
plt.grid()

# %%
from mpl_toolkits.mplot3d import Axes3D

sns.set(style = "darkgrid")

fig = plt.figure(figsize=(9.5,9.5))
ax = fig.add_subplot(111, projection = '3d')

x = df['Emi_month']
y = df['Overall_Amt']
z = df['Number of Km']

ax.set_xlabel('Emi_month')
ax.set_ylabel('Overall_Amt')
ax.set_zlabel('Number of Km')

ax.scatter(x, y, z)
plt.show()

# %%
ax = sns.violinplot(x=df["Emi_month"])

# %%
plt.figure(figsize=(23,10))
ax = sns.violinplot(x="Model", y="Number of Km", data=df)
